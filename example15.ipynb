# %% [markdown]
# # Lorem ipsum
#
# **Lorem ipsum** dolor sit amet, consectetur adipiscing elit. Nunc luctus
# bibendum felis dictum sodales.

# %%
print("hello")

# %% [markdown]
# ## Pyout

# %%
from IPython.display import HTML
HTML("""
<script>
console.log("hello");
</script>
<b>HTML</b>
""")

# %% [markdown]
# ## Image
#
# This image ![the moon](attachment:example15.png) will be included as a
# cell attachment.
